# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
training_data = pd.read_csv('./sample_data/train.csv')

# %%
training_data.head().T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
testing_data = pd.read_csv("./sample_data/test.csv")

# %%
testing_data.head().T
# Out:
#                             0                                 1  \
# PassengerId               892                               893
# Pclass                      3                                 3
# Name         Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)
# Sex                      male                            female
# Age                      34.5                              47.0
# SibSp                       0                                 1
# Parch                       0                                 0
# Ticket                 330911                            363272
# Fare                   7.8292                               7.0
# Cabin                     NaN                               NaN
# Embarked                    Q                                 S
#
#                                      2                 3  \
# PassengerId                        894               895
# Pclass                               2                 3
# ...

# %%
len(training_data), len(testing_data)
# Out:
# (891, 418)

# %%
X = training_data.drop("Survived", axis=1)
y = training_data["Survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(training_data.drop('Survived', axis=1), training_data["Survived"], test_size=0.2)

# %%
X_train.head().T
# Out:
#                                    853                   590  \
# PassengerId                        854                   591
# Pclass                               1                     3
# Name         Lines, Miss. Mary Conover  Rintamaki, Mr. Matti
# Sex                             female                  male
# Age                               16.0                  35.0
# SibSp                                0                     0
# Parch                                1                     0
# Ticket                        PC 17592     STON/O 2. 3101273
# Fare                              39.4                 7.125
# Cabin                              D28                   NaN
# Embarked                             S                     S
#
#                                        417  \
# PassengerId                            418
# Pclass                                   2
# Name         Silven, Miss. Lyyli Karoliina
# Sex                                 female
# ...

# %%
X_test.head()
# Out:
#      PassengerId  Pclass                               Name   Sex   Age  \
# 408          409       3  Birkeland, Mr. Hans Martin Monsen  male  21.0
# 839          840       1               Marechal, Mr. Pierre  male   NaN
# 282          283       3          de Pelsmaeker, Mr. Alfons  male  16.0
# 514          515       3                  Coleff, Mr. Satio  male  24.0
# 193          194       2         Navratil, Master. Michel M  male   3.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 408      0      0  312992   7.7750   NaN        S
# 839      0      0   11774  29.7000   C47        C
# 282      0      0  345778   9.5000   NaN        S
# 514      0      0  349209   7.4958   NaN        S
# 193      1      1  230080  26.0000    F2        S

# %%
lg_clf = LogisticRegression()
lg_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-166487659.py in <cell line: 0>()
#       1 lg_clf = LogisticRegression()
# ----> 2 lg_clf.fit(X_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
X_train.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            135
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          547
# Embarked         1
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
training_data.dropna(subset = ["Survived"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(training_data)
# Out:
# 891

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
pipeline =
